# %%
import pandas as pd
df = pd.read_csv("data/001_linyi_weather.csv")
df.head()
# Out:
#     name datetime  tempmax  tempmin  temp  feelslikemax  feelslikemin  \
# 0  Linyi   1/1/22      7.8     -6.4   0.1           7.0          -8.3
# 1  Linyi   1/2/22      9.1     -4.5   0.8           6.1          -9.4
# 2  Linyi   1/3/22      7.1     -5.1   0.5           6.0          -5.6
# 3  Linyi   1/4/22      4.6     -2.9   0.2           2.7          -5.0
# 4  Linyi   1/5/22      5.6     -3.0   0.7           3.5          -6.4
#
#    feelslike  dew  humidity  ...  solarenergy  uvindex  severerisk  \
# 0       -2.2 -6.2      65.3  ...         11.3        5         NaN
# 1       -2.3 -6.4      63.2  ...         11.0        5         NaN
# 2       -0.6 -5.4      67.2  ...         10.7        5         NaN
# 3       -2.7 -4.0      75.5  ...          3.4        2         NaN
# 4       -2.1 -1.8      84.3  ...          7.1        4         NaN
#
#                sunrise               sunset  moonphase  \
# 0  2022-01-01T07:45:23  2022-01-01T17:35:31       0.99
# ...

# %%
# df['tempmax'].min()
df['tempmax'].max()
# Out:
# 40.9

# %%
df['tempmin'].min()
# df['tempmin'].max()
# Out:
# -7.4

# %%
df['datetime'][df['conditions']=="Rain"]
# Out:
# 65      3/7/22
# 69     3/11/22
# 160    6/10/22
# 178    6/28/22
# 179    6/29/22
# 180    6/30/22
# 183     7/3/22
# 205    7/25/22
# 206    7/26/22
# 208    7/28/22
# 216     8/5/22
# Name: datetime, dtype: object

# %%
df[df['conditions']=="Rain"]
# Out:
#       name datetime  tempmax  tempmin  temp  feelslikemax  feelslikemin  \
# 65   Linyi   3/7/22     19.7      5.2  11.8          19.7           2.5
# 69   Linyi  3/11/22     27.2     12.8  19.0          26.4          12.8
# 160  Linyi  6/10/22     31.0     16.7  24.2          30.4          16.7
# 178  Linyi  6/28/22     33.4     22.7  28.3          32.3          22.7
# 179  Linyi  6/29/22     35.3     20.7  29.1          34.1          20.7
# 180  Linyi  6/30/22     36.9     24.3  29.6          35.3          24.3
# 183  Linyi   7/3/22     35.9     22.6  28.8          36.4          22.6
# 205  Linyi  7/25/22     33.8     22.9  28.1          37.1          22.9
# 206  Linyi  7/26/22     32.0     22.2  27.1          38.5          22.2
# 208  Linyi  7/28/22     31.6     20.3  25.7          33.1          20.3
# 216  Linyi   8/5/22     37.6     26.3  31.6          39.5          26.3
#
#      feelslike   dew  humidity  ...  solarenergy  uvindex  severerisk  \
# ...

# %%
df['sunrise'] = pd.to_datetime(df['sunrise'])
sunrize = df['sunrise']
sunrize
# Out:
# 0     2022-01-01 07:45:23
# 1     2022-01-02 07:45:34
# 2     2022-01-03 07:45:43
# 3     2022-01-04 07:45:50
# 4     2022-01-05 07:45:55
#               ...
# 226   2022-08-15 05:56:23
# 227   2022-08-16 05:57:09
# 228   2022-08-17 05:57:54
# 229   2022-08-18 05:58:40
# 230   2022-08-19 05:59:25
# Name: sunrise, Length: 231, dtype: datetime64[ns]

# %%
df['sunrise'].min()
# Out:
# Timestamp('2022-01-01 07:45:23')

# %%
df['sunrise'].max()
# Out:
# Timestamp('2022-08-19 05:59:25')

# %%
df['sunset'].min()
# Out:
# '2022-01-01T17:35:31'

# %%
df['sunset'].max()
# Out:
# '2022-08-19T19:21:25'
