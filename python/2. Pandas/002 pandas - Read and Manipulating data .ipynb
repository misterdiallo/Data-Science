# %%
import pandas as pd

df = pd.read_csv("data/002_weather.csv")

df
# Out:
#         day  event  temperature  windspeed
# 0    4/3/33   Rain         35.0        1.0
# 1   5/12/22   Snow         34.0        6.0
# 2   6/14/21   Rain          NaN       23.0
# 3   5/12/22   Rain         32.0        6.0
# 4   5/13/22   Rain          NaN        3.0
# 5   5/14/22   Snow         21.0        6.0
# 6   5/15/22   Snow         29.0       34.0
# 7    8/1/22  Sunny         35.0        6.0
# 8    8/2/22   Rain          3.0        4.0
# 9    8/3/22   Snow          7.0        6.0
# 10   7/3/22    NaN         25.0        4.0
# 11   7/4/22   Rain          NaN        6.0
# 12   7/5/22  Sunny         23.0        4.0
# 13  5/12/22  Sunny         22.0        NaN
# 14  6/14/21  Sunny          0.0        6.0
# 15  7/17/20    NaN         23.0       34.0
# 16  8/20/19   Snow         19.0        NaN

# %%
rows, columns = df.shape

# %%
rows
# Out:
# 17

# %%
columns
# Out:
# 4

# %%
df.head(3)
# Out:
#        day event  temperature  windspeed
# 0   4/3/33  Rain         35.0        1.0
# 1  5/12/22  Snow         34.0        6.0
# 2  6/14/21  Rain          NaN       23.0

# %%
df.tail(5)
# Out:
#         day  event  temperature  windspeed
# 12   7/5/22  Sunny         23.0        4.0
# 13  5/12/22  Sunny         22.0        NaN
# 14  6/14/21  Sunny          0.0        6.0
# 15  7/17/20    NaN         23.0       34.0
# 16  8/20/19   Snow         19.0        NaN

# %%
df[2:5]
# Out:
#        day event  temperature  windspeed
# 2  6/14/21  Rain          NaN       23.0
# 3  5/12/22  Rain         32.0        6.0
# 4  5/13/22  Rain          NaN        3.0

# %%
df[:]
# Out:
#         day  event  temperature  windspeed
# 0    4/3/33   Rain         35.0        1.0
# 1   5/12/22   Snow         34.0        6.0
# 2   6/14/21   Rain          NaN       23.0
# 3   5/12/22   Rain         32.0        6.0
# 4   5/13/22   Rain          NaN        3.0
# 5   5/14/22   Snow         21.0        6.0
# 6   5/15/22   Snow         29.0       34.0
# 7    8/1/22  Sunny         35.0        6.0
# 8    8/2/22   Rain          3.0        4.0
# 9    8/3/22   Snow          7.0        6.0
# 10   7/3/22    NaN         25.0        4.0
# 11   7/4/22   Rain          NaN        6.0
# 12   7/5/22  Sunny         23.0        4.0
# 13  5/12/22  Sunny         22.0        NaN
# 14  6/14/21  Sunny          0.0        6.0
# 15  7/17/20    NaN         23.0       34.0
# 16  8/20/19   Snow         19.0        NaN

# %%
df.columns
# Out:
# Index(['day', 'event', 'temperature', 'windspeed'], dtype='object')

# %%
df.day
# Out:
# 0      4/3/33
# 1     5/12/22
# 2     6/14/21
# 3     5/12/22
# 4     5/13/22
# 5     5/14/22
# 6     5/15/22
# 7      8/1/22
# 8      8/2/22
# 9      8/3/22
# 10     7/3/22
# 11     7/4/22
# 12     7/5/22
# 13    5/12/22
# 14    6/14/21
# 15    7/17/20
# 16    8/20/19
# Name: day, dtype: object

# %%
df.event
# Out:
# 0      Rain
# 1      Snow
# 2      Rain
# 3      Rain
# 4      Rain
# 5      Snow
# 6      Snow
# 7     Sunny
# 8      Rain
# 9      Snow
# 10      NaN
# 11     Rain
# 12    Sunny
# 13    Sunny
# 14    Sunny
# 15      NaN
# 16     Snow
# Name: event, dtype: object

# %%
df.temperature
# Out:
# 0     35.0
# 1     34.0
# 2      NaN
# 3     32.0
# 4      NaN
# 5     21.0
# 6     29.0
# 7     35.0
# 8      3.0
# 9      7.0
# 10    25.0
# 11     NaN
# 12    23.0
# 13    22.0
# 14     0.0
# 15    23.0
# 16    19.0
# Name: temperature, dtype: float64

# %%
type(df['day'])
# Out:
# pandas.core.series.Series

# %%
df[['day', 'temperature']]
# Out:
#         day  temperature
# 0    4/3/33         35.0
# 1   5/12/22         34.0
# 2   6/14/21          NaN
# 3   5/12/22         32.0
# 4   5/13/22          NaN
# 5   5/14/22         21.0
# 6   5/15/22         29.0
# 7    8/1/22         35.0
# 8    8/2/22          3.0
# 9    8/3/22          7.0
# 10   7/3/22         25.0
# 11   7/4/22          NaN
# 12   7/5/22         23.0
# 13  5/12/22         22.0
# 14  6/14/21          0.0
# 15  7/17/20         23.0
# 16  8/20/19         19.0

# %%
df['temperature'].max()
# Out:
# 35.0

# %%
df['temperature'].mean()
# Out:
# 22.0

# %%
df['temperature'].std()
# Out:
# 11.509193649493367

# %%
df.describe()
# Out:
#        temperature  windspeed
# count    14.000000  15.000000
# mean     22.000000   9.933333
# std      11.509194  10.924852
# min       0.000000   1.000000
# 25%      19.500000   4.000000
# 50%      23.000000   6.000000
# 75%      31.250000   6.000000
# max      35.000000  34.000000

# %%
df[df.temperature>= 32]
# Out:
#        day  event  temperature  windspeed
# 0   4/3/33   Rain         35.0        1.0
# 1  5/12/22   Snow         34.0        6.0
# 3  5/12/22   Rain         32.0        6.0
# 7   8/1/22  Sunny         35.0        6.0

# %%
df[df.temperature== df.temperature.max()]
# Out:
#       day  event  temperature  windspeed
# 0  4/3/33   Rain         35.0        1.0
# 7  8/1/22  Sunny         35.0        6.0

# %%
df[['day', 'temperature']][df.temperature== df.temperature.max()]
# Out:
#       day  temperature
# 0  4/3/33         35.0
# 7  8/1/22         35.0

# %%
df
# Out:
#         day  event  temperature  windspeed
# 0    4/3/33   Rain         35.0        1.0
# 1   5/12/22   Snow         34.0        6.0
# 2   6/14/21   Rain          NaN       23.0
# 3   5/12/22   Rain         32.0        6.0
# 4   5/13/22   Rain          NaN        3.0
# 5   5/14/22   Snow         21.0        6.0
# 6   5/15/22   Snow         29.0       34.0
# 7    8/1/22  Sunny         35.0        6.0
# 8    8/2/22   Rain          3.0        4.0
# 9    8/3/22   Snow          7.0        6.0
# 10   7/3/22    NaN         25.0        4.0
# 11   7/4/22   Rain          NaN        6.0
# 12   7/5/22  Sunny         23.0        4.0
# 13  5/12/22  Sunny         22.0        NaN
# 14  6/14/21  Sunny          0.0        6.0
# 15  7/17/20    NaN         23.0       34.0
# 16  8/20/19   Snow         19.0        NaN

# %%
df.index
# Out:
# RangeIndex(start=0, stop=17, step=1)

# %%
df.set_index('day')
# Out:
#          event  temperature  windspeed
# day
# 4/3/33    Rain         35.0        1.0
# 5/12/22   Snow         34.0        6.0
# 6/14/21   Rain          NaN       23.0
# 5/12/22   Rain         32.0        6.0
# 5/13/22   Rain          NaN        3.0
# 5/14/22   Snow         21.0        6.0
# 5/15/22   Snow         29.0       34.0
# 8/1/22   Sunny         35.0        6.0
# 8/2/22    Rain          3.0        4.0
# 8/3/22    Snow          7.0        6.0
# 7/3/22     NaN         25.0        4.0
# 7/4/22    Rain          NaN        6.0
# 7/5/22   Sunny         23.0        4.0
# 5/12/22  Sunny         22.0        NaN
# 6/14/21  Sunny          0.0        6.0
# 7/17/20    NaN         23.0       34.0
# 8/20/19   Snow         19.0        NaN

# %%
df
# Out:
#         day  event  temperature  windspeed
# 0    4/3/33   Rain         35.0        1.0
# 1   5/12/22   Snow         34.0        6.0
# 2   6/14/21   Rain          NaN       23.0
# 3   5/12/22   Rain         32.0        6.0
# 4   5/13/22   Rain          NaN        3.0
# 5   5/14/22   Snow         21.0        6.0
# 6   5/15/22   Snow         29.0       34.0
# 7    8/1/22  Sunny         35.0        6.0
# 8    8/2/22   Rain          3.0        4.0
# 9    8/3/22   Snow          7.0        6.0
# 10   7/3/22    NaN         25.0        4.0
# 11   7/4/22   Rain          NaN        6.0
# 12   7/5/22  Sunny         23.0        4.0
# 13  5/12/22  Sunny         22.0        NaN
# 14  6/14/21  Sunny          0.0        6.0
# 15  7/17/20    NaN         23.0       34.0
# 16  8/20/19   Snow         19.0        NaN

# %%
df.set_index('day', inplace=True)

# %%
df
# Out:
#          event  temperature  windspeed
# day
# 4/3/33    Rain         35.0        1.0
# 5/12/22   Snow         34.0        6.0
# 6/14/21   Rain          NaN       23.0
# 5/12/22   Rain         32.0        6.0
# 5/13/22   Rain          NaN        3.0
# 5/14/22   Snow         21.0        6.0
# 5/15/22   Snow         29.0       34.0
# 8/1/22   Sunny         35.0        6.0
# 8/2/22    Rain          3.0        4.0
# 8/3/22    Snow          7.0        6.0
# 7/3/22     NaN         25.0        4.0
# 7/4/22    Rain          NaN        6.0
# 7/5/22   Sunny         23.0        4.0
# 5/12/22  Sunny         22.0        NaN
# 6/14/21  Sunny          0.0        6.0
# 7/17/20    NaN         23.0       34.0
# 8/20/19   Snow         19.0        NaN

# %%
df.loc['7/3/22']
# Out:
# event           NaN
# temperature    25.0
# windspeed       4.0
# Name: 7/3/22, dtype: object

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#         day  event  temperature  windspeed
# 0    4/3/33   Rain         35.0        1.0
# 1   5/12/22   Snow         34.0        6.0
# 2   6/14/21   Rain          NaN       23.0
# 3   5/12/22   Rain         32.0        6.0
# 4   5/13/22   Rain          NaN        3.0
# 5   5/14/22   Snow         21.0        6.0
# 6   5/15/22   Snow         29.0       34.0
# 7    8/1/22  Sunny         35.0        6.0
# 8    8/2/22   Rain          3.0        4.0
# 9    8/3/22   Snow          7.0        6.0
# 10   7/3/22    NaN         25.0        4.0
# 11   7/4/22   Rain          NaN        6.0
# 12   7/5/22  Sunny         23.0        4.0
# 13  5/12/22  Sunny         22.0        NaN
# 14  6/14/21  Sunny          0.0        6.0
# 15  7/17/20    NaN         23.0       34.0
# 16  8/20/19   Snow         19.0        NaN

# %%
df.set_index('event', inplace=True)

# %%
df
# Out:
#            day  temperature  windspeed
# event
# Rain    4/3/33         35.0        1.0
# Snow   5/12/22         34.0        6.0
# Rain   6/14/21          NaN       23.0
# Rain   5/12/22         32.0        6.0
# Rain   5/13/22          NaN        3.0
# Snow   5/14/22         21.0        6.0
# Snow   5/15/22         29.0       34.0
# Sunny   8/1/22         35.0        6.0
# Rain    8/2/22          3.0        4.0
# Snow    8/3/22          7.0        6.0
# NaN     7/3/22         25.0        4.0
# Rain    7/4/22          NaN        6.0
# Sunny   7/5/22         23.0        4.0
# Sunny  5/12/22         22.0        NaN
# Sunny  6/14/21          0.0        6.0
# NaN    7/17/20         23.0       34.0
# Snow   8/20/19         19.0        NaN

# %%
df.loc['Rain']
# Out:
#            day  temperature  windspeed
# event
# Rain    4/3/33         35.0        1.0
# Rain   6/14/21          NaN       23.0
# Rain   5/12/22         32.0        6.0
# Rain   5/13/22          NaN        3.0
# Rain    8/2/22          3.0        4.0
# Rain    7/4/22          NaN        6.0
